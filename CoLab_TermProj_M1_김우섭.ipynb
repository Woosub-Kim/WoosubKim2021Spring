# %% [markdown]
# # 생물정보학 및 실습 1 - Term Project용 환경 셋업
#
# ```
# 생물정보학 및 실습 1
# 서울대학교 협동과정 생물정보학전공 2021년 1학기
#
# 이 노트북은 Creative Commons BY-SA 조건으로 재사용 가능합니다.
# 장혜식 <hyeshik@snu.ac.kr>, 서울대학교 생명과학부
# ```
#
# 이 노트북은 Google Colab을 이용해서 Term Project를 할 수 있도록 환경을 준비해 줍니다. 터미널 사용이 원활하지 않은 상태이고, 데이터를 오랫동안 보관하기 어렵기 때문에 되도록 개인용 컴퓨터에서 [Anaconda](https://www.anaconda.com/)나 [JupyterLab](https://jupyterlab.readthedocs.io/en/stable/) 등을 설치하고 사용하시는 것이 편하지만, 개인용 컴퓨터 사양이 부족한 경우에는 Google CoLab을 사용할 수도 있습니다. 개인용 컴퓨터를 쓸 때는 Windows에서는 [WSL2](https://docs.microsoft.com/en-us/windows/wsl/install-win10)를 쓰시면 리눅스 커맨드라인 환경을 쓸 수 있습니다. Google Colab은 창을 닫은 후 90분 후, 또는 창을 처음 열고 12시간 후에 환경을 닫아버리기 때문에 매번 실습할 때마다 새로 셋업이 필요합니다. `Runtime->Run All`을 실행해서 전체를 한 번 실행하시면 준비됩니다. 모든 것이 잘 안 되고 뭔가 꼬인 느낌이 강하게 들 때는 `Runtime->Factory reset runtime`을 누르고 새로 시작하시면 될 수도 있습니다.

# %% [markdown]
# ## Google Drive 마운트
#
# 데이터 파일들을 불러오고 저장하기 위해서 Google Drive를 연결합니다. **이번엔 스크립트 파일을 편집해야 하기 때문에 Google Drive 마운트를 하지 않으면 vim등 콘솔에서 쓸 수 있는 에디터를 쓰셔야 합니다.** 화면에 나오는 주소를 눌러서 인증하고 인증 코드를 그 아래에 입력하세요. 그러면 `/contents/drive/MyDrive`에서 자신의 Drive 최상단 폴더가 보입니다.

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# ## 실습용 Bioconda 환경 설치하기
# 실습용 프로그램들을 쉽게 설치할 수 있도록 [Bioconda](https://bioconda.github.io/) 환경을 만듭니다. 실행하고 진행상황을 관찰하다가 에러로 보이는 것이 있으면 잘 읽어보고 해결합니다.
#
# 파이썬 모듈들은 Colab쪽의 파이썬 인터프리터를 바꿀 수 없기 때문에 Conda에 설치하더라도 사용하기 어렵습니다. 파이썬 모듈은 `pip` 명령어로 설치하시면 Colab에서 불러와서 사용할 수 있습니다.
#
# 환경 초기화에 관련된 스크립트는 [GitHub 프로젝트](https://github.com/hyeshik/colab-biolab)에 있습니다.

# %%
# !git clone https://github.com/hyeshik/colab-biolab.git
# !cd colab-biolab && bash tools/setup.sh
exec(open('colab-biolab/tools/activate_conda.py').read())
# Out:
# Cloning into 'colab-biolab'...
# remote: Enumerating objects: 69, done.
# remote: Counting objects: 100% (69/69), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 69 (delta 22), reused 54 (delta 13), pack-reused 0
# Unpacking objects: 100% (69/69), done.
# ./
# ./root/
# ./root/.bashrc.biolab
# ./root/.bin.priority/
# ./root/.bin.priority/pip
# ./root/.bin.priority/pip2
# ./root/.bin.priority/pip3
# ./root/.condarc
# ./root/.profile
# ./root/.tmux.conf
# ./root/.vimrc
# --2021-05-27 09:22:36--  https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.131.3, 104.16.130.3, 2606:4700::6810:8203, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.131.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 94235922 (90M) [application/x-sh]
# Saving to: ‘miniconda3.sh’
#
# miniconda3.sh       100%[===================>]  89.87M  43.8MB/s    in 2.1s
#
# 2021-05-27 09:22:38 (43.8 MB/s) - ‘miniconda3.sh’ saved [94235922/94235922]
#
# PREFIX=/root/conda
# Unpacking payload ...
# done
# done
#
# # All requested packages already installed.
#
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /root/conda
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.10.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /root/conda/envs/lab
#
#   added / updated specs:
#     - bedtools
#     - biopython
#     - bwa
#     - cython
#     - matplotlib
#     - numpy
#     - pandas
#     - pip
#     - pysam
#     - samtools
#     - scipy
#     - star
#
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      conda-forge/linux-64::_libgcc_mutex-0.1-conda_forge
#   _openmp_mutex      conda-forge/linux-64::_openmp_mutex-4.5-1_gnu
#   bedtools           bioconda/linux-64::bedtools-2.30.0-h7d7f7ad_1
#   biopython          conda-forge/linux-64::biopython-1.78-py37h5e8e339_2
#   bwa                bioconda/linux-64::bwa-0.7.17-h5bf99c6_8
#   bzip2              conda-forge/linux-64::bzip2-1.0.8-h7f98852_4
#   c-ares             conda-forge/linux-64::c-ares-1.17.1-h7f98852_1
#   ca-certificates    conda-forge/linux-64::ca-certificates-2020.12.5-ha878542_0
#   certifi            conda-forge/linux-64::certifi-2020.12.5-py37h89c1867_1
#   cycler             conda-forge/noarch::cycler-0.10.0-py_2
#   cython             conda-forge/linux-64::cython-0.29.23-py37hcd2ae1e_0
#   dbus               conda-forge/linux-64::dbus-1.13.6-h48d8840_2
#   expat              conda-forge/linux-64::expat-2.4.1-h9c3ff4c_0
#   fontconfig         conda-forge/linux-64::fontconfig-2.13.1-hba837de_1005
#   freetype           conda-forge/linux-64::freetype-2.10.4-h0708190_1
#   gettext            conda-forge/linux-64::gettext-0.19.8.1-h0b5b191_1005
#   glib               conda-forge/linux-64::glib-2.68.2-h9c3ff4c_0
#   glib-tools         conda-forge/linux-64::glib-tools-2.68.2-h9c3ff4c_0
#   gst-plugins-base   pkgs/main/linux-64::gst-plugins-base-1.14.0-hbbd80ab_1
#   gstreamer          pkgs/main/linux-64::gstreamer-1.14.0-h28cd5cc_2
#   htslib             bioconda/linux-64::htslib-1.12-h9093b5e_1
#   icu                conda-forge/linux-64::icu-58.2-hf484d3e_1000
#   jbig               conda-forge/linux-64::jbig-2.1-h7f98852_2003
#   jpeg               conda-forge/linux-64::jpeg-9d-h36c2ea0_0
#   kiwisolver         conda-forge/linux-64::kiwisolver-1.3.1-py37h2527ec5_1
#   krb5               conda-forge/linux-64::krb5-1.19.1-hcc1bbae_0
#   lcms2              conda-forge/linux-64::lcms2-2.12-hddcbb42_0
#   ld_impl_linux-64   conda-forge/linux-64::ld_impl_linux-64-2.35.1-hea4e1c9_2
#   lerc               conda-forge/linux-64::lerc-2.2.1-h9c3ff4c_0
#   libblas            conda-forge/linux-64::libblas-3.9.0-9_openblas
#   libcblas           conda-forge/linux-64::libcblas-3.9.0-9_openblas
#   libcurl            conda-forge/linux-64::libcurl-7.77.0-h2574ce0_0
#   libdeflate         conda-forge/linux-64::libdeflate-1.7-h7f98852_5
#   libedit            conda-forge/linux-64::libedit-3.1.20191231-he28a2e2_2
#   libev              conda-forge/linux-64::libev-4.33-h516909a_1
#   libffi             conda-forge/linux-64::libffi-3.3-h58526e2_2
#   libgcc-ng          conda-forge/linux-64::libgcc-ng-9.3.0-h2828fa1_19
#   libgfortran-ng     conda-forge/linux-64::libgfortran-ng-9.3.0-hff62375_19
#   libgfortran5       conda-forge/linux-64::libgfortran5-9.3.0-hff62375_19
#   libglib            conda-forge/linux-64::libglib-2.68.2-h3e27bee_0
#   libgomp            conda-forge/linux-64::libgomp-9.3.0-h2828fa1_19
#   libiconv           conda-forge/linux-64::libiconv-1.16-h516909a_0
#   liblapack          conda-forge/linux-64::liblapack-3.9.0-9_openblas
#   libnghttp2         conda-forge/linux-64::libnghttp2-1.43.0-h812cca2_0
#   libopenblas        conda-forge/linux-64::libopenblas-0.3.15-pthreads_h8fe5266_1
#   libpng             conda-forge/linux-64::libpng-1.6.37-h21135ba_2
#   libssh2            conda-forge/linux-64::libssh2-1.9.0-ha56f1ee_6
#   libstdcxx-ng       conda-forge/linux-64::libstdcxx-ng-9.3.0-h6de172a_19
#   libtiff            conda-forge/linux-64::libtiff-4.3.0-hf544144_1
#   libuuid            conda-forge/linux-64::libuuid-2.32.1-h7f98852_1000
#   libwebp-base       conda-forge/linux-64::libwebp-base-1.2.0-h7f98852_2
#   libxcb             conda-forge/linux-64::libxcb-1.13-h7f98852_1003
#   libxml2            pkgs/main/linux-64::libxml2-2.9.10-hb55368b_3
#   lz4-c              conda-forge/linux-64::lz4-c-1.9.3-h9c3ff4c_0
#   matplotlib         conda-forge/linux-64::matplotlib-3.4.2-py37h89c1867_0
#   matplotlib-base    conda-forge/linux-64::matplotlib-base-3.4.2-py37hdd32ed1_0
#   ncurses            conda-forge/linux-64::ncurses-6.2-h58526e2_4
#   numpy              conda-forge/linux-64::numpy-1.20.3-py37h038b26d_1
#   olefile            conda-forge/noarch::olefile-0.46-pyh9f0ad1d_1
#   openjpeg           conda-forge/linux-64::openjpeg-2.4.0-hb52868f_1
#   openssl            conda-forge/linux-64::openssl-1.1.1k-h7f98852_0
#   pandas             conda-forge/linux-64::pandas-1.2.4-py37h219a48f_0
#   pcre               conda-forge/linux-64::pcre-8.44-he1b5a44_0
#   perl               conda-forge/linux-64::perl-5.32.0-h36c2ea0_0
#   pillow             conda-forge/linux-64::pillow-8.2.0-py37h4600e1f_1
#   pip                conda-forge/noarch::pip-21.1.2-pyhd8ed1ab_0
#   pthread-stubs      conda-forge/linux-64::pthread-stubs-0.4-h36c2ea0_1001
#   pyparsing          conda-forge/noarch::pyparsing-2.4.7-pyh9f0ad1d_0
#   pyqt               conda-forge/linux-64::pyqt-5.9.2-py37hcca6a23_4
#   pysam              bioconda/linux-64::pysam-0.16.0.1-py37h45aed0b_3
#   python             conda-forge/linux-64::python-3.7.10-hffdb5ce_100_cpython
#   python-dateutil    conda-forge/noarch::python-dateutil-2.8.1-py_0
#   python_abi         conda-forge/linux-64::python_abi-3.7-1_cp37m
#   pytz               conda-forge/noarch::pytz-2021.1-pyhd8ed1ab_0
#   qt                 pkgs/main/linux-64::qt-5.9.7-h5867ecd_1
#   readline           conda-forge/linux-64::readline-8.1-h46c0cb4_0
#   samtools           bioconda/linux-64::samtools-1.12-h9aed4be_1
#   scipy              conda-forge/linux-64::scipy-1.6.3-py37h29e03ee_0
#   setuptools         conda-forge/linux-64::setuptools-49.6.0-py37h89c1867_3
#   sip                pkgs/main/linux-64::sip-4.19.8-py37hf484d3e_0
#   six                conda-forge/noarch::six-1.16.0-pyh6c4a22f_0
#   sqlite             conda-forge/linux-64::sqlite-3.35.5-h74cdb3f_0
#   star               bioconda/linux-64::star-2.7.9a-h9ee0642_0
#   tk                 conda-forge/linux-64::tk-8.6.10-h21135ba_1
#   tornado            conda-forge/linux-64::tornado-6.1-py37h5e8e339_1
#   wheel              conda-forge/noarch::wheel-0.36.2-pyhd3deb0d_0
#   xorg-libxau        conda-forge/linux-64::xorg-libxau-1.0.9-h7f98852_0
#   xorg-libxdmcp      conda-forge/linux-64::xorg-libxdmcp-1.1.3-h7f98852_0
#   xz                 conda-forge/linux-64::xz-5.2.5-h516909a_1
#   zlib               conda-forge/linux-64::zlib-1.2.11-h516909a_1010
#   zstd               conda-forge/linux-64::zstd-1.5.0-ha95c52a_0
#
#
# done
# done
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate lab
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# Activated conda environment `lab'!

# %% [markdown]
# 설정이 끝났으면, 이제 콘솔을 열어서 터미널로 접속할 수 있는 통로를 열어줍니다.

# %% [markdown]
# ## Google Drive에 시퀀싱 데이터 다운로드
# 이제 실습 수업에서 필요한 시퀀싱 데이터를 다운로드 받아서 설치합시다. 드라이브 공간만 충분하면 데이터는 계속 저장돼 있기 때문에 한 번만 하시면 됩니다. Colab에서는 작업용 데이터를 Google Drive 폴더 아래의 `binfo-datapack1`에 저장합니다. 실습용 데이터는 `/content/drive/MyDrive/binfo1-datapack1`에 풀리게 됩니다. 첫 번째에는 wget이 접속오류를 내는 경우가 많으니, 접속에러가 발생하면 다시 한 번 실행해 보세요. 1G씩 끊어지지만 자동으로 이어받아집니다.

# %%
# !wget -O - --no-check-certificate https://hyeshik.qbio.io/binfo/binfo1-datapack1.tar | tar -C /content/drive/MyDrive -xf -
# Out:
# '\n!wget -O - --no-check-certificate https://hyeshik.qbio.io/binfo/binfo1-datapack1.tar | tar -C /content/drive/MyDrive -xf -\n'

# %% [markdown]
# 받은 데이터의 MD5 체크섬을 확인합니다. 한참 걸립니다. 각 파일들의 원래 체크섬은 다음과 같습니다. 한 번 비교해 보세요.
#
# ```
# 140aaf30bcb9276cc716f8699f04ddd6  CLIP-35L33G.bam
# f1b3336ed7e2f97d562dcc71641251bd  CLIP-35L33G.bam.bai
# 328883a73d507eafbf5b60bd6b906201  RNA-control.bam
# 02073818e2f398a73c3b76e5169de1ca  RNA-control.bam.bai
# b09550d09d6c2a4ce27f0226f426fdb1  RNA-siLin28a.bam
# fef112c727244060ea62d3f2564a07f6  RNA-siLin28a.bam.bai
# 28bbd0c47d725669340c784f1b772c01  RNA-siLuc.bam
# 43590fdc4d81905c0432e0d1cb8cfd5b  RNA-siLuc.bam.bai
# 5c08a9297307bc83259e658c4474f0cc  RPF-siLin28a.bam
# a1bb3e29be412dfd7fd8d16b1b1acc4c  RPF-siLin28a.bam.bai
# f2eebf50943024d0116c9cd3e744c707  RPF-siLuc.bam
# dc24f69e8f571fc8be30f28ce5b84fcd  RPF-siLuc.bam.bai
# ```

# %%
# !md5sum /content/drive/MyDrive/BioLab/binfo1-datapack1/*
# Out:
# 140aaf30bcb9276cc716f8699f04ddd6  /content/drive/MyDrive/BioLab/binfo1-datapack1/CLIP-35L33G.bam
# f1b3336ed7e2f97d562dcc71641251bd  /content/drive/MyDrive/BioLab/binfo1-datapack1/CLIP-35L33G.bam.bai
# d54d428f5872030c4ffc43058709b896  /content/drive/MyDrive/BioLab/binfo1-datapack1/gencode.gtf
# 794eb8d273987a094dcc013afa2a1956  /content/drive/MyDrive/BioLab/binfo1-datapack1/gencode.gtf.gz
# f691d94ca9c72e6feedbfe4561dd5b83  /content/drive/MyDrive/BioLab/binfo1-datapack1/read-counts.txt
# 7c9528c08ed2f1ae6e2de599db1aa8fb  /content/drive/MyDrive/BioLab/binfo1-datapack1/read-counts.txt.summary
# 328883a73d507eafbf5b60bd6b906201  /content/drive/MyDrive/BioLab/binfo1-datapack1/RNA-control.bam
# 02073818e2f398a73c3b76e5169de1ca  /content/drive/MyDrive/BioLab/binfo1-datapack1/RNA-control.bam.bai
# b09550d09d6c2a4ce27f0226f426fdb1  /content/drive/MyDrive/BioLab/binfo1-datapack1/RNA-siLin28a.bam
# fef112c727244060ea62d3f2564a07f6  /content/drive/MyDrive/BioLab/binfo1-datapack1/RNA-siLin28a.bam.bai
# 28bbd0c47d725669340c784f1b772c01  /content/drive/MyDrive/BioLab/binfo1-datapack1/RNA-siLuc.bam
# 43590fdc4d81905c0432e0d1cb8cfd5b  /content/drive/MyDrive/BioLab/binfo1-datapack1/RNA-siLuc.bam.bai
# 5c08a9297307bc83259e658c4474f0cc  /content/drive/MyDrive/BioLab/binfo1-datapack1/RPF-siLin28a.bam
# a1bb3e29be412dfd7fd8d16b1b1acc4c  /content/drive/MyDrive/BioLab/binfo1-datapack1/RPF-siLin28a.bam.bai
# f2eebf50943024d0116c9cd3e744c707  /content/drive/MyDrive/BioLab/binfo1-datapack1/RPF-siLuc.bam
# dc24f69e8f571fc8be30f28ce5b84fcd  /content/drive/MyDrive/BioLab/binfo1-datapack1/RPF-siLuc.bam.bai

# %% [markdown]
# 그리고, GENCODE Annotation 데이터도 미리 받아서 저장해 둡니다. 에러가 나면 다시 한 번 실행해 봅니다.

# %%
# !wget --no-check-certificate -O /content/drive/MyDrive/binfo1-datapack1/gencode.gtf.gz http://ftp.ebi.ac.uk/pub/databases/gencode/Gencode_mouse/release_M27/gencode.vM27.annotation.gtf.gz
# Out:
# --2021-05-13 09:45:48--  http://ftp.ebi.ac.uk/pub/databases/gencode/Gencode_mouse/release_M27/gencode.vM27.annotation.gtf.gz
# Resolving ftp.ebi.ac.uk (ftp.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.ebi.ac.uk (ftp.ebi.ac.uk)|193.62.193.138|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 28359457 (27M) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/binfo1-datapack1/gencode.gtf.gz’
#
# /content/drive/MyDr 100%[===================>]  27.04M   803KB/s    in 35s
#
# 2021-05-13 09:46:24 (789 KB/s) - ‘/content/drive/MyDrive/binfo1-datapack1/gencode.gtf.gz’ saved [28359457/28359457]

# %% [markdown]
# 다루기 쉽도록 Annotation 압축을 풉니다.

# %%
# !gunzip /content/drive/MyDrive/BioLab/binfo1-datapack1/gencode.gtf.gz
# Out:
# gzip: /content/drive/MyDrive/BioLab/binfo1-datapack1/gencode.gtf already exists; do you wish to overwrite (y or n)? y

# %%
# !ls -al /content/drive/MyDrive/BioLab/binfo*
# Out:
# total 7160208
# -rw------- 1 root root 1370036258 May 27 08:48 CLIP-35L33G.bam
# -rw------- 1 root root    3118336 May 27 08:48 CLIP-35L33G.bam.bai
# -rw------- 1 root root  883334756 May 27 08:33 gencode.gtf
# -rw------- 1 root root   24065406 May 17 06:01 read-counts.txt
# -rw------- 1 root root        751 May 17 06:01 read-counts.txt.summary
# -rw------- 1 root root 1003658801 May 27 08:49 RNA-control.bam
# -rw------- 1 root root    2276104 May 27 08:49 RNA-control.bam.bai
# -rw------- 1 root root 1260991122 May 27 08:52 RNA-siLin28a.bam
# -rw------- 1 root root    2710744 May 27 08:52 RNA-siLin28a.bam.bai
# -rw------- 1 root root  981684502 May 27 08:53 RNA-siLuc.bam
# -rw------- 1 root root    2606104 May 27 08:53 RNA-siLuc.bam.bai
# -rw------- 1 root root  737352902 May 27 08:54 RPF-siLin28a.bam
# -rw------- 1 root root    2482768 May 27 08:54 RPF-siLin28a.bam.bai
# -rw------- 1 root root 1055123479 May 27 08:56 RPF-siLuc.bam
# -rw------- 1 root root    2605912 May 27 08:56 RPF-siLuc.bam.bai

# %% [markdown]
# 실습에 필요한 프로그램들 몇 가지를 추가로 설치합니다.

# %%
# !conda install -y subread
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.10.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /root/conda/envs/lab
#
#   added / updated specs:
#     - subread
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     subread-2.0.1              |       h5bf99c6_1        22.8 MB  bioconda
#     ------------------------------------------------------------
#                                            Total:        22.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   subread            bioconda/linux-64::subread-2.0.1-h5bf99c6_1
#
#
#
# Downloading and Extracting Packages
# subread-2.0.1        | 22.8 MB   | : 100% 1.0/1 [00:03<00:00,  3.70s/it]
# done
# done
# done

# %% [markdown]
# ## Transcript count table 마련하기
#
# 제공된 alignment와 annotation 파일들을 이용해서 transcript별 read count를 구해봅니다. 실제 연구에서는 multi-mapping 등을 고려해야 하지만, 여기서는 단순화해서 모두 무시합니다. 데이터가 있는 곳으로 이동해서 작업합시다.

# %%
# %cd /content/drive/MyDrive/BioLab/binfo1-datapack1/
# Out:
# /content/drive/MyDrive/BioLab/binfo1-datapack1

# %%
# !featureCounts -a gencode.gtf -o read-counts.txt *.bam
# Out:
#         ==========     _____ _    _ ____  _____  ______          _____
#         =====         / ____| |  | |  _ \|  __ \|  ____|   /\   |  __ \
#           =====      | (___ | |  | | |_) | |__) | |__     /  \  | |  | |
#             ====      \___ \| |  | |  _ <|  _  /|  __|   / /\ \ | |  | |
#               ====    ____) | |__| | |_) | | \ \| |____ / ____ \| |__| |
#         ==========   |_____/ \____/|____/|_|  \_\______/_/    \_\_____/
# 	  v2.0.1
#
# //========================== featureCounts setting ===========================\\
# ||                                                                            ||
# ||             Input files : 6 BAM files                                      ||
# ||                           o CLIP-35L33G.bam                                ||
# ||                           o RNA-control.bam                                ||
# ||                           o RNA-siLin28a.bam                               ||
# ||                           o RNA-siLuc.bam                                  ||
# ||                           o RPF-siLin28a.bam                               ||
# ||                           o RPF-siLuc.bam                                  ||
# ||                                                                            ||
# ||             Output file : read-counts.txt                                  ||
# ||                 Summary : read-counts.txt.summary                          ||
# ||              Annotation : gencode.gtf (GTF)                                ||
# ||      Dir for temp files : ./                                               ||
# ||                                                                            ||
# ||                 Threads : 1                                                ||
# ||                   Level : meta-feature level                               ||
# ||              Paired-end : no                                               ||
# ||      Multimapping reads : not counted                                      ||
# || Multi-overlapping reads : not counted                                      ||
# ||   Min overlapping bases : 1                                                ||
# ||                                                                            ||
# \\============================================================================//
#
# //================================= Running ==================================\\
# ||                                                                            ||
# || Load annotation file gencode.gtf ...                                       ||
# ||    Features : 841952                                                       ||
# ||    Meta-features : 55359                                                   ||
# ||    Chromosomes/contigs : 22                                                ||
# ||                                                                            ||
# || Process BAM file CLIP-35L33G.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 38880853                                             ||
# ||    Successfully assigned alignments : 13630945 (35.1%)                     ||
# ||    Running time : 0.98 minutes                                             ||
# ||                                                                            ||
# || Process BAM file RNA-control.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 24971058                                             ||
# ||    Successfully assigned alignments : 5200836 (20.8%)                      ||
# ||    Running time : 0.66 minutes                                             ||
# ||                                                                            ||
# || Process BAM file RNA-siLin28a.bam...                                       ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 35108178                                             ||
# ||    Successfully assigned alignments : 12338280 (35.1%)                     ||
# ||    Running time : 0.89 minutes                                             ||
# ||                                                                            ||
# || Process BAM file RNA-siLuc.bam...                                          ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 28117241                                             ||
# ||    Successfully assigned alignments : 9748787 (34.7%)                      ||
# ||    Running time : 0.70 minutes                                             ||
# ||                                                                            ||
# || Process BAM file RPF-siLin28a.bam...                                       ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 30095551                                             ||
# ||    Successfully assigned alignments : 10694162 (35.5%)                     ||
# ||    Running time : 0.60 minutes                                             ||
# ||                                                                            ||
# || Process BAM file RPF-siLuc.bam...                                          ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 42002435                                             ||
# ||    Successfully assigned alignments : 12932285 (30.8%)                     ||
# ||    Running time : 0.85 minutes                                             ||
# ||                                                                            ||
# || Write the final count table.                                               ||
# || Write the read assignment summary.                                         ||
# ||                                                                            ||
# || Summary of counting results can be found in file "read-counts.txt.summary  ||
# || "                                                                          ||
# ||                                                                            ||
# \\============================================================================//

# %% [markdown]
# 결과를 pandas로 읽어와 봅니다.

# %%
import pandas as pd
cnts = pd.read_csv('read-counts.txt', sep='\t', comment='#', index_col=0)
cnts.head()
# Out:
#                                                      Chr  ... RPF-siLuc.bam
# Geneid                                                    ...
# ENSMUSG00000102693.2                                chr1  ...             0
# ENSMUSG00000064842.3                                chr1  ...             0
# ENSMUSG00000051951.6  chr1;chr1;chr1;chr1;chr1;chr1;chr1  ...             0
# ENSMUSG00000102851.2                                chr1  ...             0
# ENSMUSG00000103377.2                                chr1  ...             0
#
# [5 rows x 11 columns]

# %%
cnts.columns
# Out:
# Index(['Chr', 'Start', 'End', 'Strand', 'Length', 'CLIP-35L33G.bam',
#        'RNA-control.bam', 'RNA-siLin28a.bam', 'RNA-siLuc.bam',
#        'RPF-siLin28a.bam', 'RPF-siLuc.bam'],
#       dtype='object')

# %% [markdown]
# 이제 한 번 대충 그림을 그려 봅니다.

# %%
cnts['clip_enrichment'] = cnts['CLIP-35L33G.bam'] / cnts['RNA-control.bam']
cnts['rden_change'] = (cnts['RPF-siLin28a.bam'] / cnts['RNA-siLin28a.bam']) / (cnts['RPF-siLuc.bam'] / cnts['RNA-siLuc.bam'])
cnts.head()
# Out:
#                                                      Chr  ... rden_change
# Geneid                                                    ...
# ENSMUSG00000102693.2                                chr1  ...         NaN
# ENSMUSG00000064842.3                                chr1  ...         NaN
# ENSMUSG00000051951.6  chr1;chr1;chr1;chr1;chr1;chr1;chr1  ...         NaN
# ENSMUSG00000102851.2                                chr1  ...         NaN
# ENSMUSG00000103377.2                                chr1  ...         NaN
#
# [5 rows x 13 columns]

# %%
from matplotlib import pyplot as plt
import numpy as np

fig, ax = plt.subplots(1, 1, figsize=(5, 5))
ax.scatter(np.log2(cnts['clip_enrichment']),
           np.log2(cnts['rden_change']))
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:726: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# 이 그림에는 문제가 많이 있습니다. 논문의 그림처럼 한 번 만들어 봅시다~

# %% [markdown]
# ## Protein localization 반영하기
#
# 논문 그림에서는 protein localization을 반영해서 색으로 나타냈습니다. 이것을 한 번 구현해 봅시다. 각 gene product의 localization을 따로 구하려면 좀 귀찮기 때문에 미리 모아 두었습니다. UniProt에서 매핑된 데이터를 토대로 아주 명확한 것만 일부 정리한 것입니다. 이것도 마찬가지로 처음엔 에러가 나기도 하니까, 다시 실행해보면 거의 잘 됩니다~

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
mouselocal = pd.read_csv('https://hyeshik.qbio.io/binfo/mouselocalization-20210507.txt', sep='\t')
mouselocal
# Out:
#                  gene_id            Gene names               type
# 0     ENSMUSG00000000001                 Gnai3          cytoplasm
# 1     ENSMUSG00000000028  Cdc45 Cdc45l Cdc45l2            nucleus
# 2     ENSMUSG00000000049            Apoh B2gp1          cytoplasm
# 3     ENSMUSG00000000058                  Cav2          cytoplasm
# 4     ENSMUSG00000000085                 Scmh1            nucleus
# ...                  ...                   ...                ...
# 9518  ENSMUSG00000117975       Itprip Kiaa1754  integral membrane
# 9519  ENSMUSG00000118332  Fam220a Acpin1 Sipar            nucleus
# 9520  ENSMUSG00000118346              Tmem179b  integral membrane
# 9521  ENSMUSG00000118504                   NaN  integral membrane
# 9522  ENSMUSG00000118560                  Lim2  integral membrane
#
# [9523 rows x 3 columns]

# %% [markdown]
# 이제 이 localization 데이터와 위에서 만든 scatter를 결합해서 논문 그림과 비슷하게 만들어 봅시다.

# %%
gene_id_dict = {}
for i in range(len(mouselocal)):
  gene_id_dict[mouselocal.iloc[i]['gene_id']] = mouselocal.iloc[i]['type']

# gene_id_dict

# %%
A = pd.Series(cnts.index).apply(lambda x: gene_id_dict[x.split('.')[0]] if x.split('.')[0] in gene_id_dict else '' )
B = np.log2(cnts['clip_enrichment'])
C = np.log2(cnts['rden_change'])
cnts2 = pd.DataFrame({'Loc':list(A), 'clip_enrichment':list(B), 'rden_change':C})
cnts2 = cnts2[cnts2.Loc != ''] 
cnts2
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:726: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#                                      Loc  clip_enrichment  rden_change
# Geneid
# ENSMUSG00000051951.6   integral membrane         2.000000          NaN
# ENSMUSG00000025902.14            nucleus         2.584963    -1.263034
# ENSMUSG00000025903.15          cytoplasm         1.832978    -0.395057
# ENSMUSG00000002459.18            nucleus         2.321928     3.584963
# ENSMUSG00000025905.15  integral membrane         5.614710     0.192645
# ...                                  ...              ...          ...
# ENSMUSG00000064360.1   integral membrane             -inf     0.073063
# ENSMUSG00000065947.1   integral membrane        -1.584963    -1.000000
# ENSMUSG00000064363.1   integral membrane        -2.527089     0.146816
# ENSMUSG00000064367.1   integral membrane        -0.526998     0.337168
# ENSMUSG00000064368.1   integral membrane        -0.246195     0.337745
#
# [9414 rows x 3 columns]

# %%
# Scatter plot with a different color by groups
groups = cnts2.groupby('Loc')
fig, ax = plt.subplots()
for name, group in groups:
    ax.plot(group.clip_enrichment, 
            group.rden_change, 
            marker='o', 
            linestyle='',
            label=name)

ax.legend(fontsize=12, loc='upper left') # legend position
plt.show()
